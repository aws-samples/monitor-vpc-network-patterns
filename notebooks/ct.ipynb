# %% [markdown]
# # Processing CloudTrail logs
#
# This notebook shows how to process CloudTrail log data using Spark.
#
# ## License
#
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved.
# SPDX-License-Identifier: MIT-0
#
# ## Assumptions
#
# * CloudTrail is enabled and writing logs into an S3 bucket in the standard year/month/day format
#
# ## Goals
#
# * Periodically take latest data and reformat it for more efficient query and storage
#
# ## Approach
#
# * Turn on S3 object expiration for raw data (not shown here)
# * At some interval, perhaps nightly, process the latest CT data.  Doing this daily makes the job easier as we can load up the latest partition.  This notebook contains most of that logic except for the orchestration.  We could kick off a job using the Glue scheduler or Step Functions triggered by a CloudWatch scheduled event.
# * Convert to Parquet and set partition structure.  In this example we use the region and event source, but normally we'd include the date as well.
# * Append to existing processed data set (not shown here)

# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

sc = SparkContext.getOrCreate()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>3</td><td>application_1586272817950_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-32-61-164.us-east-2.compute.internal:20888/proxy/application_1586272817950_0004/">Link</a></td><td><a target="_blank" href="http://ip-172-32-50-161.us-east-2.compute.internal:8042/node/containerlogs/container_1586272817950_0004_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Load in one day's worth of logs from one region
ct_bucket = '<name of S3 bucket containing CloudTrail logs>'
acct = '<your account number>'
region = '<AWS region>'
ct_dt = '<date of interest, e.g. 2020/04/01>'
df = spark.read.json('s3://' + ct_bucket + '/AWSLogs/' + acct + '/CloudTrail/' + region + '/' + ct_dt + '/*.gz')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df.count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 1854

# %%
df.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- Records: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- additionalEventData: struct (nullable = true)
#  |    |    |    |-- AuthenticationMethod: string (nullable = true)
#  |    |    |    |-- CipherSuite: string (nullable = true)
#  |    |    |    |-- SSEApplied: string (nullable = true)
#  |    |    |    |-- SignatureVersion: string (nullable = true)
#  |    |    |    |-- bytesTransferredIn: double (nullable = true)
#  |    |    |    |-- bytesTransferredOut: double (nullable = true)
#  |    |    |    |-- capabilities: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- clone: boolean (nullable = true)
#  |    |    |    |-- configRuleArn: string (nullable = true)
#  |    |    |    |-- configRuleInputParameters: string (nullable = true)
#  |    |    |    |-- configRuleName: string (nullable = true)
#  |    |    |    |-- dataTransferred: boolean (nullable = true)
#  |    |    |    |-- managedRuleIdentifier: string (nullable = true)
#  |    |    |    |-- notificationJobType: string (nullable = true)
#  |    |    |    |-- protocol: string (nullable = true)
#  |    |    |    |-- repositoryId: string (nullable = true)
#  |    |    |    |-- repositoryName: string (nullable = true)
#  |    |    |    |-- service: string (nullable = true)
#  |    |    |    |-- shallow: boolean (nullable = true)
#  |    |    |    |-- vpcEndpointId: string (nullable = true)
#  |    |    |    |-- x-amz-id-2: string (nullable = true)
#  |    |    |-- apiVersion: string (nullable = true)
#  |    |    |-- awsRegion: string (nullable = true)
#  |    |    |-- errorCode: string (nullable = true)
#  |    |    |-- errorMessage: string (nullable = true)
#  |    |    |-- eventCategory: string (nullable = true)
#  |    |    |-- eventID: string (nullable = true)
#  |    |    |-- eventName: string (nullable = true)
#  |    |    |-- eventSource: string (nullable = true)
#  |    |    |-- eventTime: string (nullable = true)
#  |    |    |-- eventType: string (nullable = true)
#  |    |    |-- eventVersion: string (nullable = true)
#  |    |    |-- managementEvent: boolean (nullable = true)
#  |    |    |-- readOnly: boolean (nullable = true)
#  |    |    |-- recipientAccountId: string (nullable = true)
#  |    |    |-- requestID: string (nullable = true)
#  |    |    |-- requestParameters: struct (nullable = true)
#  |    |    |    |-- CompleteMultipartUpload: struct (nullable = true)
#  |    |    |    |    |-- Part: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- ETag: string (nullable = true)
#  |    |    |    |    |    |    |-- PartNumber: double (nullable = true)
#  |    |    |    |-- DescribeByoipCidrsRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- DescribeEgressOnlyInternetGatewaysRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- DescribeFlowLogsRequest: struct (nullable = true)
#  |    |    |    |    |-- Filter: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |    |    |    |-- Value: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- content: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- tag: long (nullable = true)
#  |    |    |    |    |    |    |-- tag: long (nullable = true)
#  |    |    |    |-- DescribeHostsRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- DescribeNatGatewaysRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- DescribeVpcEndpointServiceConfigurationsRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- DescribeVpcEndpointsRequest: struct (nullable = true)
#  |    |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |    |-- Filters: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |    |    |-- Values: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- GroupName: string (nullable = true)
#  |    |    |    |-- Host: string (nullable = true)
#  |    |    |    |-- acl: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- bucketName: string (nullable = true)
#  |    |    |    |-- configRuleName: string (nullable = true)
#  |    |    |    |-- configurationRecorderNames: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- cors: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- documentName: string (nullable = true)
#  |    |    |    |-- durationSeconds: long (nullable = true)
#  |    |    |    |-- encryption: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- encryptionAlgorithm: string (nullable = true)
#  |    |    |    |-- encryptionContext: struct (nullable = true)
#  |    |    |    |    |-- aws:cloudtrail:arn: string (nullable = true)
#  |    |    |    |    |-- aws:codecommit:env-alg: string (nullable = true)
#  |    |    |    |    |-- aws:codecommit:id: string (nullable = true)
#  |    |    |    |    |-- aws:codecommit:sig-alg: string (nullable = true)
#  |    |    |    |    |-- aws:lambda:FunctionArn: string (nullable = true)
#  |    |    |    |    |-- aws:s3:arn: string (nullable = true)
#  |    |    |    |-- evaluations: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- annotation: string (nullable = true)
#  |    |    |    |    |    |-- complianceResourceId: string (nullable = true)
#  |    |    |    |    |    |-- complianceResourceType: string (nullable = true)
#  |    |    |    |    |    |-- complianceType: string (nullable = true)
#  |    |    |    |    |    |-- orderingTimestamp: string (nullable = true)
#  |    |    |    |-- expression: string (nullable = true)
#  |    |    |    |-- externalId: string (nullable = true)
#  |    |    |    |-- filterSet: struct (nullable = true)
#  |    |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- valueSet: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- functionName: string (nullable = true)
#  |    |    |    |-- host: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- includeDeletedResources: boolean (nullable = true)
#  |    |    |    |-- includeManagedAlarms: boolean (nullable = true)
#  |    |    |    |-- includePublic: boolean (nullable = true)
#  |    |    |    |-- includeShared: boolean (nullable = true)
#  |    |    |    |-- includes: struct (nullable = true)
#  |    |    |    |    |-- hasDnsFqdn: boolean (nullable = true)
#  |    |    |    |    |-- keyTypes: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- instanceIds: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- interactive: boolean (nullable = true)
#  |    |    |    |-- key: string (nullable = true)
#  |    |    |    |-- keyId: string (nullable = true)
#  |    |    |    |-- keySpec: string (nullable = true)
#  |    |    |    |-- lifecycle: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- limit: long (nullable = true)
#  |    |    |    |-- loadBalancerArn: string (nullable = true)
#  |    |    |    |-- location: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- logGroupName: string (nullable = true)
#  |    |    |    |-- logStreamName: string (nullable = true)
#  |    |    |    |-- logging: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- maxConcurrency: string (nullable = true)
#  |    |    |    |-- maxErrors: string (nullable = true)
#  |    |    |    |-- maxItems: long (nullable = true)
#  |    |    |    |-- maxRecords: long (nullable = true)
#  |    |    |    |-- maxResults: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- nextToken: string (nullable = true)
#  |    |    |    |-- notification: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- numberOfBytes: long (nullable = true)
#  |    |    |    |-- object-lock: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- parameterGroupName: string (nullable = true)
#  |    |    |    |-- parameters: struct (nullable = true)
#  |    |    |    |    |-- Operation: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- SnapshotId: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- partNumber: string (nullable = true)
#  |    |    |    |-- policy: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- policyName: string (nullable = true)
#  |    |    |    |-- policyStatus: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- publicAccessBlock: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- references: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- commit: string (nullable = true)
#  |    |    |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- replication: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- repositoryName: string (nullable = true)
#  |    |    |    |-- requestPayment: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- resourceArn: string (nullable = true)
#  |    |    |    |-- resourceArns: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- resourceIdList: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- resourceKeys: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- resourceId: string (nullable = true)
#  |    |    |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |-- resourceName: string (nullable = true)
#  |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |-- resourceTypeFilters: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- resourcesPerPage: long (nullable = true)
#  |    |    |    |-- resultToken: string (nullable = true)
#  |    |    |    |-- roleArn: string (nullable = true)
#  |    |    |    |-- roleSessionName: string (nullable = true)
#  |    |    |    |-- serviceNamespace: string (nullable = true)
#  |    |    |    |-- streamCreationTimestamp: string (nullable = true)
#  |    |    |    |-- streamName: string (nullable = true)
#  |    |    |    |-- tableName: string (nullable = true)
#  |    |    |    |-- tagFilters: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- values: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- tagging: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- targetGroupArn: string (nullable = true)
#  |    |    |    |-- testMode: boolean (nullable = true)
#  |    |    |    |-- timeoutSeconds: long (nullable = true)
#  |    |    |    |-- topicArn: string (nullable = true)
#  |    |    |    |-- trailName: string (nullable = true)
#  |    |    |    |-- uploadId: string (nullable = true)
#  |    |    |    |-- uploads: string (nullable = true)
#  |    |    |    |-- versioning: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- website: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- x-amz-acl: string (nullable = true)
#  |    |    |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |    |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |    |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |    |    |-- resources: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- ARN: string (nullable = true)
#  |    |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- responseElements: struct (nullable = true)
#  |    |    |    |-- assumedRoleUser: struct (nullable = true)
#  |    |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |    |-- assumedRoleId: string (nullable = true)
#  |    |    |    |-- certificateSummaryList: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- clusterSubnetGroups: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- clusterSubnetGroupName: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- subnetGroupStatus: string (nullable = true)
#  |    |    |    |    |    |-- subnets: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- subnetAvailabilityZone: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- subnetIdentifier: string (nullable = true)
#  |    |    |    |    |    |    |    |-- subnetStatus: string (nullable = true)
#  |    |    |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- vpcId: string (nullable = true)
#  |    |    |    |-- clusters: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- credentials: struct (nullable = true)
#  |    |    |    |    |-- accessKeyId: string (nullable = true)
#  |    |    |    |    |-- expiration: string (nullable = true)
#  |    |    |    |    |-- sessionToken: string (nullable = true)
#  |    |    |    |-- eventSubscriptionsList: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- parameterGroups: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- parameterGroupFamily: string (nullable = true)
#  |    |    |    |    |    |-- parameterGroupName: string (nullable = true)
#  |    |    |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- parameters: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- allowedValues: string (nullable = true)
#  |    |    |    |    |    |-- applyType: string (nullable = true)
#  |    |    |    |    |    |-- dataType: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- isModifiable: boolean (nullable = true)
#  |    |    |    |    |    |-- parameterName: string (nullable = true)
#  |    |    |    |    |    |-- parameterValue: string (nullable = true)
#  |    |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |-- repositoryMetadata: struct (nullable = true)
#  |    |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |    |-- cloneUrlHttp: string (nullable = true)
#  |    |    |    |    |-- cloneUrlSsh: string (nullable = true)
#  |    |    |    |    |-- creationDate: string (nullable = true)
#  |    |    |    |    |-- lastModifiedDate: string (nullable = true)
#  |    |    |    |    |-- repositoryId: string (nullable = true)
#  |    |    |    |    |-- repositoryName: string (nullable = true)
#  |    |    |    |-- snapshots: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |    |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |    |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |    |    |    |-- x-amz-version-id: string (nullable = true)
#  |    |    |-- sharedEventID: string (nullable = true)
#  |    |    |-- sourceIPAddress: string (nullable = true)
#  |    |    |-- userAgent: string (nullable = true)
#  |    |    |-- userIdentity: struct (nullable = true)
#  |    |    |    |-- accessKeyId: string (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |-- invokedBy: string (nullable = true)
#  |    |    |    |-- principalId: string (nullable = true)
#  |    |    |    |-- sessionContext: struct (nullable = true)
#  |    |    |    |    |-- attributes: struct (nullable = true)
#  |    |    |    |    |    |-- creationDate: string (nullable = true)
#  |    |    |    |    |    |-- mfaAuthenticated: string (nullable = true)
#  |    |    |    |    |-- sessionIssuer: struct (nullable = true)
#  |    |    |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |    |    |-- principalId: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- userName: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- userName: string (nullable = true)
#  |    |    |-- vpcEndpointId: string (nullable = true)

# %%
from pyspark.sql.functions import explode
dfLong = df.select(explode(df.Records))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
dfLong.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- col: struct (nullable = true)
#  |    |-- additionalEventData: struct (nullable = true)
#  |    |    |-- AuthenticationMethod: string (nullable = true)
#  |    |    |-- CipherSuite: string (nullable = true)
#  |    |    |-- SSEApplied: string (nullable = true)
#  |    |    |-- SignatureVersion: string (nullable = true)
#  |    |    |-- bytesTransferredIn: double (nullable = true)
#  |    |    |-- bytesTransferredOut: double (nullable = true)
#  |    |    |-- capabilities: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- clone: boolean (nullable = true)
#  |    |    |-- configRuleArn: string (nullable = true)
#  |    |    |-- configRuleInputParameters: string (nullable = true)
#  |    |    |-- configRuleName: string (nullable = true)
#  |    |    |-- dataTransferred: boolean (nullable = true)
#  |    |    |-- managedRuleIdentifier: string (nullable = true)
#  |    |    |-- notificationJobType: string (nullable = true)
#  |    |    |-- protocol: string (nullable = true)
#  |    |    |-- repositoryId: string (nullable = true)
#  |    |    |-- repositoryName: string (nullable = true)
#  |    |    |-- service: string (nullable = true)
#  |    |    |-- shallow: boolean (nullable = true)
#  |    |    |-- vpcEndpointId: string (nullable = true)
#  |    |    |-- x-amz-id-2: string (nullable = true)
#  |    |-- apiVersion: string (nullable = true)
#  |    |-- awsRegion: string (nullable = true)
#  |    |-- errorCode: string (nullable = true)
#  |    |-- errorMessage: string (nullable = true)
#  |    |-- eventCategory: string (nullable = true)
#  |    |-- eventID: string (nullable = true)
#  |    |-- eventName: string (nullable = true)
#  |    |-- eventSource: string (nullable = true)
#  |    |-- eventTime: string (nullable = true)
#  |    |-- eventType: string (nullable = true)
#  |    |-- eventVersion: string (nullable = true)
#  |    |-- managementEvent: boolean (nullable = true)
#  |    |-- readOnly: boolean (nullable = true)
#  |    |-- recipientAccountId: string (nullable = true)
#  |    |-- requestID: string (nullable = true)
#  |    |-- requestParameters: struct (nullable = true)
#  |    |    |-- CompleteMultipartUpload: struct (nullable = true)
#  |    |    |    |-- Part: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ETag: string (nullable = true)
#  |    |    |    |    |    |-- PartNumber: double (nullable = true)
#  |    |    |-- DescribeByoipCidrsRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- DescribeEgressOnlyInternetGatewaysRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- DescribeFlowLogsRequest: struct (nullable = true)
#  |    |    |    |-- Filter: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |    |    |-- Value: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- content: string (nullable = true)
#  |    |    |    |    |    |    |    |-- tag: long (nullable = true)
#  |    |    |    |    |    |-- tag: long (nullable = true)
#  |    |    |-- DescribeHostsRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- DescribeNatGatewaysRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- DescribeVpcEndpointServiceConfigurationsRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- DescribeVpcEndpointsRequest: struct (nullable = true)
#  |    |    |    |-- MaxResults: long (nullable = true)
#  |    |    |-- Filters: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |    |-- Values: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- GroupName: string (nullable = true)
#  |    |    |-- Host: string (nullable = true)
#  |    |    |-- acl: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- bucketName: string (nullable = true)
#  |    |    |-- configRuleName: string (nullable = true)
#  |    |    |-- configurationRecorderNames: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- cors: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- documentName: string (nullable = true)
#  |    |    |-- durationSeconds: long (nullable = true)
#  |    |    |-- encryption: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- encryptionAlgorithm: string (nullable = true)
#  |    |    |-- encryptionContext: struct (nullable = true)
#  |    |    |    |-- aws:cloudtrail:arn: string (nullable = true)
#  |    |    |    |-- aws:codecommit:env-alg: string (nullable = true)
#  |    |    |    |-- aws:codecommit:id: string (nullable = true)
#  |    |    |    |-- aws:codecommit:sig-alg: string (nullable = true)
#  |    |    |    |-- aws:lambda:FunctionArn: string (nullable = true)
#  |    |    |    |-- aws:s3:arn: string (nullable = true)
#  |    |    |-- evaluations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- annotation: string (nullable = true)
#  |    |    |    |    |-- complianceResourceId: string (nullable = true)
#  |    |    |    |    |-- complianceResourceType: string (nullable = true)
#  |    |    |    |    |-- complianceType: string (nullable = true)
#  |    |    |    |    |-- orderingTimestamp: string (nullable = true)
#  |    |    |-- expression: string (nullable = true)
#  |    |    |-- externalId: string (nullable = true)
#  |    |    |-- filterSet: struct (nullable = true)
#  |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- valueSet: struct (nullable = true)
#  |    |    |    |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- functionName: string (nullable = true)
#  |    |    |-- host: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- includeDeletedResources: boolean (nullable = true)
#  |    |    |-- includeManagedAlarms: boolean (nullable = true)
#  |    |    |-- includePublic: boolean (nullable = true)
#  |    |    |-- includeShared: boolean (nullable = true)
#  |    |    |-- includes: struct (nullable = true)
#  |    |    |    |-- hasDnsFqdn: boolean (nullable = true)
#  |    |    |    |-- keyTypes: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- instanceIds: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- interactive: boolean (nullable = true)
#  |    |    |-- key: string (nullable = true)
#  |    |    |-- keyId: string (nullable = true)
#  |    |    |-- keySpec: string (nullable = true)
#  |    |    |-- lifecycle: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- limit: long (nullable = true)
#  |    |    |-- loadBalancerArn: string (nullable = true)
#  |    |    |-- location: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- logGroupName: string (nullable = true)
#  |    |    |-- logStreamName: string (nullable = true)
#  |    |    |-- logging: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- maxConcurrency: string (nullable = true)
#  |    |    |-- maxErrors: string (nullable = true)
#  |    |    |-- maxItems: long (nullable = true)
#  |    |    |-- maxRecords: long (nullable = true)
#  |    |    |-- maxResults: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- nextToken: string (nullable = true)
#  |    |    |-- notification: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- numberOfBytes: long (nullable = true)
#  |    |    |-- object-lock: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- parameterGroupName: string (nullable = true)
#  |    |    |-- parameters: struct (nullable = true)
#  |    |    |    |-- Operation: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- SnapshotId: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- partNumber: string (nullable = true)
#  |    |    |-- policy: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- policyName: string (nullable = true)
#  |    |    |-- policyStatus: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- publicAccessBlock: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- references: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- commit: string (nullable = true)
#  |    |    |    |    |-- ref: string (nullable = true)
#  |    |    |-- replication: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- repositoryName: string (nullable = true)
#  |    |    |-- requestPayment: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- resourceArn: string (nullable = true)
#  |    |    |-- resourceArns: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- resourceIdList: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- resourceKeys: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- resourceId: string (nullable = true)
#  |    |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |-- resourceName: string (nullable = true)
#  |    |    |-- resourceType: string (nullable = true)
#  |    |    |-- resourceTypeFilters: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- resourcesPerPage: long (nullable = true)
#  |    |    |-- resultToken: string (nullable = true)
#  |    |    |-- roleArn: string (nullable = true)
#  |    |    |-- roleSessionName: string (nullable = true)
#  |    |    |-- serviceNamespace: string (nullable = true)
#  |    |    |-- streamCreationTimestamp: string (nullable = true)
#  |    |    |-- streamName: string (nullable = true)
#  |    |    |-- tableName: string (nullable = true)
#  |    |    |-- tagFilters: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |-- values: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- tagging: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- targetGroupArn: string (nullable = true)
#  |    |    |-- testMode: boolean (nullable = true)
#  |    |    |-- timeoutSeconds: long (nullable = true)
#  |    |    |-- topicArn: string (nullable = true)
#  |    |    |-- trailName: string (nullable = true)
#  |    |    |-- uploadId: string (nullable = true)
#  |    |    |-- uploads: string (nullable = true)
#  |    |    |-- versioning: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- website: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- x-amz-acl: string (nullable = true)
#  |    |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |    |-- resources: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ARN: string (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- responseElements: struct (nullable = true)
#  |    |    |-- assumedRoleUser: struct (nullable = true)
#  |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |-- assumedRoleId: string (nullable = true)
#  |    |    |-- certificateSummaryList: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- clusterSubnetGroups: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- clusterSubnetGroupName: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- subnetGroupStatus: string (nullable = true)
#  |    |    |    |    |-- subnets: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- subnetAvailabilityZone: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- subnetIdentifier: string (nullable = true)
#  |    |    |    |    |    |    |-- subnetStatus: string (nullable = true)
#  |    |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- vpcId: string (nullable = true)
#  |    |    |-- clusters: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- credentials: struct (nullable = true)
#  |    |    |    |-- accessKeyId: string (nullable = true)
#  |    |    |    |-- expiration: string (nullable = true)
#  |    |    |    |-- sessionToken: string (nullable = true)
#  |    |    |-- eventSubscriptionsList: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- parameterGroups: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- parameterGroupFamily: string (nullable = true)
#  |    |    |    |    |-- parameterGroupName: string (nullable = true)
#  |    |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- parameters: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- allowedValues: string (nullable = true)
#  |    |    |    |    |-- applyType: string (nullable = true)
#  |    |    |    |    |-- dataType: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- isModifiable: boolean (nullable = true)
#  |    |    |    |    |-- parameterName: string (nullable = true)
#  |    |    |    |    |-- parameterValue: string (nullable = true)
#  |    |    |    |    |-- source: string (nullable = true)
#  |    |    |-- repositoryMetadata: struct (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |-- cloneUrlHttp: string (nullable = true)
#  |    |    |    |-- cloneUrlSsh: string (nullable = true)
#  |    |    |    |-- creationDate: string (nullable = true)
#  |    |    |    |-- lastModifiedDate: string (nullable = true)
#  |    |    |    |-- repositoryId: string (nullable = true)
#  |    |    |    |-- repositoryName: string (nullable = true)
#  |    |    |-- snapshots: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |    |    |-- x-amz-version-id: string (nullable = true)
#  |    |-- sharedEventID: string (nullable = true)
#  |    |-- sourceIPAddress: string (nullable = true)
#  |    |-- userAgent: string (nullable = true)
#  |    |-- userIdentity: struct (nullable = true)
#  |    |    |-- accessKeyId: string (nullable = true)
#  |    |    |-- accountId: string (nullable = true)
#  |    |    |-- arn: string (nullable = true)
#  |    |    |-- invokedBy: string (nullable = true)
#  |    |    |-- principalId: string (nullable = true)
#  |    |    |-- sessionContext: struct (nullable = true)
#  |    |    |    |-- attributes: struct (nullable = true)
#  |    |    |    |    |-- creationDate: string (nullable = true)
#  |    |    |    |    |-- mfaAuthenticated: string (nullable = true)
#  |    |    |    |-- sessionIssuer: struct (nullable = true)
#  |    |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |    |-- principalId: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- userName: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- userName: string (nullable = true)
#  |    |-- vpcEndpointId: string (nullable = true)

# %%
dfLong.count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 50849

# %%
dfLong.head(1)

# %%
dfUpOneLevel = dfLong.select("col.*")
dfUpOneLevel.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- additionalEventData: struct (nullable = true)
#  |    |-- AuthenticationMethod: string (nullable = true)
#  |    |-- CipherSuite: string (nullable = true)
#  |    |-- SSEApplied: string (nullable = true)
#  |    |-- SignatureVersion: string (nullable = true)
#  |    |-- bytesTransferredIn: double (nullable = true)
#  |    |-- bytesTransferredOut: double (nullable = true)
#  |    |-- capabilities: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- clone: boolean (nullable = true)
#  |    |-- configRuleArn: string (nullable = true)
#  |    |-- configRuleInputParameters: string (nullable = true)
#  |    |-- configRuleName: string (nullable = true)
#  |    |-- dataTransferred: boolean (nullable = true)
#  |    |-- managedRuleIdentifier: string (nullable = true)
#  |    |-- notificationJobType: string (nullable = true)
#  |    |-- protocol: string (nullable = true)
#  |    |-- repositoryId: string (nullable = true)
#  |    |-- repositoryName: string (nullable = true)
#  |    |-- service: string (nullable = true)
#  |    |-- shallow: boolean (nullable = true)
#  |    |-- vpcEndpointId: string (nullable = true)
#  |    |-- x-amz-id-2: string (nullable = true)
#  |-- apiVersion: string (nullable = true)
#  |-- awsRegion: string (nullable = true)
#  |-- errorCode: string (nullable = true)
#  |-- errorMessage: string (nullable = true)
#  |-- eventCategory: string (nullable = true)
#  |-- eventID: string (nullable = true)
#  |-- eventName: string (nullable = true)
#  |-- eventSource: string (nullable = true)
#  |-- eventTime: string (nullable = true)
#  |-- eventType: string (nullable = true)
#  |-- eventVersion: string (nullable = true)
#  |-- managementEvent: boolean (nullable = true)
#  |-- readOnly: boolean (nullable = true)
#  |-- recipientAccountId: string (nullable = true)
#  |-- requestID: string (nullable = true)
#  |-- requestParameters: struct (nullable = true)
#  |    |-- CompleteMultipartUpload: struct (nullable = true)
#  |    |    |-- Part: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- ETag: string (nullable = true)
#  |    |    |    |    |-- PartNumber: double (nullable = true)
#  |    |-- DescribeByoipCidrsRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- DescribeEgressOnlyInternetGatewaysRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- DescribeFlowLogsRequest: struct (nullable = true)
#  |    |    |-- Filter: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |    |-- Value: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- content: string (nullable = true)
#  |    |    |    |    |    |    |-- tag: long (nullable = true)
#  |    |    |    |    |-- tag: long (nullable = true)
#  |    |-- DescribeHostsRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- DescribeNatGatewaysRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- DescribeVpcEndpointServiceConfigurationsRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- DescribeVpcEndpointsRequest: struct (nullable = true)
#  |    |    |-- MaxResults: long (nullable = true)
#  |    |-- Filters: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Name: string (nullable = true)
#  |    |    |    |-- Values: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- GroupName: string (nullable = true)
#  |    |-- Host: string (nullable = true)
#  |    |-- acl: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- bucketName: string (nullable = true)
#  |    |-- configRuleName: string (nullable = true)
#  |    |-- configurationRecorderNames: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- cors: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- documentName: string (nullable = true)
#  |    |-- durationSeconds: long (nullable = true)
#  |    |-- encryption: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- encryptionAlgorithm: string (nullable = true)
#  |    |-- encryptionContext: struct (nullable = true)
#  |    |    |-- aws:cloudtrail:arn: string (nullable = true)
#  |    |    |-- aws:codecommit:env-alg: string (nullable = true)
#  |    |    |-- aws:codecommit:id: string (nullable = true)
#  |    |    |-- aws:codecommit:sig-alg: string (nullable = true)
#  |    |    |-- aws:lambda:FunctionArn: string (nullable = true)
#  |    |    |-- aws:s3:arn: string (nullable = true)
#  |    |-- evaluations: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- annotation: string (nullable = true)
#  |    |    |    |-- complianceResourceId: string (nullable = true)
#  |    |    |    |-- complianceResourceType: string (nullable = true)
#  |    |    |    |-- complianceType: string (nullable = true)
#  |    |    |    |-- orderingTimestamp: string (nullable = true)
#  |    |-- expression: string (nullable = true)
#  |    |-- externalId: string (nullable = true)
#  |    |-- filterSet: struct (nullable = true)
#  |    |    |-- items: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- valueSet: struct (nullable = true)
#  |    |    |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |-- functionName: string (nullable = true)
#  |    |-- host: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- includeDeletedResources: boolean (nullable = true)
#  |    |-- includeManagedAlarms: boolean (nullable = true)
#  |    |-- includePublic: boolean (nullable = true)
#  |    |-- includeShared: boolean (nullable = true)
#  |    |-- includes: struct (nullable = true)
#  |    |    |-- hasDnsFqdn: boolean (nullable = true)
#  |    |    |-- keyTypes: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- instanceIds: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- interactive: boolean (nullable = true)
#  |    |-- key: string (nullable = true)
#  |    |-- keyId: string (nullable = true)
#  |    |-- keySpec: string (nullable = true)
#  |    |-- lifecycle: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- limit: long (nullable = true)
#  |    |-- loadBalancerArn: string (nullable = true)
#  |    |-- location: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- logGroupName: string (nullable = true)
#  |    |-- logStreamName: string (nullable = true)
#  |    |-- logging: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- maxConcurrency: string (nullable = true)
#  |    |-- maxErrors: string (nullable = true)
#  |    |-- maxItems: long (nullable = true)
#  |    |-- maxRecords: long (nullable = true)
#  |    |-- maxResults: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nextToken: string (nullable = true)
#  |    |-- notification: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- numberOfBytes: long (nullable = true)
#  |    |-- object-lock: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- parameterGroupName: string (nullable = true)
#  |    |-- parameters: struct (nullable = true)
#  |    |    |-- Operation: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- SnapshotId: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- partNumber: string (nullable = true)
#  |    |-- policy: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- policyName: string (nullable = true)
#  |    |-- policyStatus: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- publicAccessBlock: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- references: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- commit: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |-- replication: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- repositoryName: string (nullable = true)
#  |    |-- requestPayment: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- resourceArn: string (nullable = true)
#  |    |-- resourceArns: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- resourceIdList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- resourceKeys: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- resourceId: string (nullable = true)
#  |    |    |    |-- resourceType: string (nullable = true)
#  |    |-- resourceName: string (nullable = true)
#  |    |-- resourceType: string (nullable = true)
#  |    |-- resourceTypeFilters: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- resourcesPerPage: long (nullable = true)
#  |    |-- resultToken: string (nullable = true)
#  |    |-- roleArn: string (nullable = true)
#  |    |-- roleSessionName: string (nullable = true)
#  |    |-- serviceNamespace: string (nullable = true)
#  |    |-- streamCreationTimestamp: string (nullable = true)
#  |    |-- streamName: string (nullable = true)
#  |    |-- tableName: string (nullable = true)
#  |    |-- tagFilters: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- key: string (nullable = true)
#  |    |    |    |-- values: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- tagging: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- targetGroupArn: string (nullable = true)
#  |    |-- testMode: boolean (nullable = true)
#  |    |-- timeoutSeconds: long (nullable = true)
#  |    |-- topicArn: string (nullable = true)
#  |    |-- trailName: string (nullable = true)
#  |    |-- uploadId: string (nullable = true)
#  |    |-- uploads: string (nullable = true)
#  |    |-- versioning: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- website: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- x-amz-acl: string (nullable = true)
#  |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |-- resources: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ARN: string (nullable = true)
#  |    |    |-- accountId: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- responseElements: struct (nullable = true)
#  |    |-- assumedRoleUser: struct (nullable = true)
#  |    |    |-- arn: string (nullable = true)
#  |    |    |-- assumedRoleId: string (nullable = true)
#  |    |-- certificateSummaryList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- clusterSubnetGroups: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- clusterSubnetGroupName: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- subnetGroupStatus: string (nullable = true)
#  |    |    |    |-- subnets: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- subnetAvailabilityZone: struct (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- subnetIdentifier: string (nullable = true)
#  |    |    |    |    |    |-- subnetStatus: string (nullable = true)
#  |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- vpcId: string (nullable = true)
#  |    |-- clusters: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- credentials: struct (nullable = true)
#  |    |    |-- accessKeyId: string (nullable = true)
#  |    |    |-- expiration: string (nullable = true)
#  |    |    |-- sessionToken: string (nullable = true)
#  |    |-- eventSubscriptionsList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- parameterGroups: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- parameterGroupFamily: string (nullable = true)
#  |    |    |    |-- parameterGroupName: string (nullable = true)
#  |    |    |    |-- tags: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- parameters: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- allowedValues: string (nullable = true)
#  |    |    |    |-- applyType: string (nullable = true)
#  |    |    |    |-- dataType: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- isModifiable: boolean (nullable = true)
#  |    |    |    |-- parameterName: string (nullable = true)
#  |    |    |    |-- parameterValue: string (nullable = true)
#  |    |    |    |-- source: string (nullable = true)
#  |    |-- repositoryMetadata: struct (nullable = true)
#  |    |    |-- accountId: string (nullable = true)
#  |    |    |-- arn: string (nullable = true)
#  |    |    |-- cloneUrlHttp: string (nullable = true)
#  |    |    |-- cloneUrlSsh: string (nullable = true)
#  |    |    |-- creationDate: string (nullable = true)
#  |    |    |-- lastModifiedDate: string (nullable = true)
#  |    |    |-- repositoryId: string (nullable = true)
#  |    |    |-- repositoryName: string (nullable = true)
#  |    |-- snapshots: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- x-amz-server-side-encryption: string (nullable = true)
#  |    |-- x-amz-server-side-encryption-aws-kms-key-id: string (nullable = true)
#  |    |-- x-amz-server-side-encryption-context: string (nullable = true)
#  |    |-- x-amz-version-id: string (nullable = true)
#  |-- sharedEventID: string (nullable = true)
#  |-- sourceIPAddress: string (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userIdentity: struct (nullable = true)
#  |    |-- accessKeyId: string (nullable = true)
#  |    |-- accountId: string (nullable = true)
#  |    |-- arn: string (nullable = true)
#  |    |-- invokedBy: string (nullable = true)
#  |    |-- principalId: string (nullable = true)
#  |    |-- sessionContext: struct (nullable = true)
#  |    |    |-- attributes: struct (nullable = true)
#  |    |    |    |-- creationDate: string (nullable = true)
#  |    |    |    |-- mfaAuthenticated: string (nullable = true)
#  |    |    |-- sessionIssuer: struct (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- arn: string (nullable = true)
#  |    |    |    |-- principalId: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- userName: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- userName: string (nullable = true)
#  |-- vpcEndpointId: string (nullable = true)

# %%
dfUpOneLevel.write.partitionBy("awsRegion","eventSource").parquet("s3://" + ct_bucket + "/parquet_pt/")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
